# %%
print('athiRa'.upper())
# Out:
# ATHIRA

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(10*3)
# Out:
# 30

# %%
x=30
print(type(x))
# Out:
# <class 'int'>

# %%
print(32, 'sky' ,'god' ,54 , sep='&')
# Out:
# 32&sky&god&54

# %%
# whenever input is taken from the user , the default data type is always string,so if its not string - do typecasting

# %%
# and= if all expressions are true , it returns true
# or = false if all the statements are false, true : if atlast one is true
# not = opposite scenario

# %%
x='python'
print('n' in 'python')
# Out:
# True

# %% [markdown]
# '==' checks for values (need not be exactly the same), but 'is' checks for the exact thing that is 'is' operator checks for both value plus datatype
#
#
# else is known as DEFAULT BLOCK
# -ELSE is always related to the immediate just before block , not to every statements above, only to the last ifblock
# -if blocks can exist alone , but else cannot, it comes only afer if or elif
# - anything that exists is taken as true
# - true stands for 1,and anything that exista like earth, sun, moon etc...
# - null, empty,false, all are 0 and the same

# %% [markdown]
# # STRINGS

# %%
w='PYTHON'
print(w[0])
print(len(w))
# Out:
# P
# 6

# %%
w='python'
print(w[ : :1])
print(w[ : :-1])
# Out:
# python
# nohtyp

# %%
a='hello'
b='world'
print(a+b)
print(a+'    '+b)
# Out:
# helloworld
# hello    world

# %%
w='python'
print(w[ : :2]*2)
# Out:
# ptopto

# %%
print(9*3)
print('9'*3)
# Out:
# 27
# 999

# %%
# opeartions done on strings like uppercase,lowercase, if its to be done they must be stored back again
w='python'
print(w.upper())
w=w.upper
# Out:
# PYTHON

# %%
w='    python     is good'
w.strip()
# Out:
# 'python     is good'

# %%
# give w.lower() and w.strip() where ever there is a chance that the user makes a mistake

# %%
x='analysis'
print(x.count('a'))
print(x.replace('s','z'))
print(x.find('l'))
# Out:
# 2
# analyziz
# 3

# %%
b='you have got to go or you will be punished'
print(b.find('you',1))
# Out:
# 22

# %%
c='            python'
print(c.ljust(10))
print(c.rjust(10))
print(c.center(20))
# Out:
#             python
#             python
#              python

# %%
a=input('enter your age: ')
b=input ('enter your salary: ')
c=input('enter name: ')
print(f'the candidate name is {c} and his age is {a} , he earns {b} dollars')
# Out:
# enter your age: 54
# enter your salary: 1500
# enter name: steve
# the candidate name is steve and his age is 54 , he earns 1500 dollars

# %%
a='athira@90'
print(a.isalpha())
print(a.isalnum())
b='@#$%^&*'
print(b.isalpha())
# Out:
# False
# False
# False
